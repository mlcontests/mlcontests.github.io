# %%
import pandas as pd
import json

# %%
with open('competitions.json', 'r') as f:
    t = json.load(f)

# %%
t['data']
# Out:
# [{'name': 'Multi-Source Prim-Dijkstra Contest',
#   'url': 'https://github.com/TILOS-AI-Institute/Multi-Source-Prim-Dijkstra/tree/main/contest',
#   'type': '📉 Optimisation',
#   'tags': ['optimisation', 'measurable'],
#   'launched': '22 Jun 2023',
#   'registration-deadline': '15 Jun 2023',
#   'deadline': '10 Nov 2023',
#   'prize': '$7,600',
#   'platform': 'Independent',
#   'sponsor': 'TILOS AI Institute',
#   'conference': 'ISQED',
#   'conference-year': 2023},
#  {'name': 'Kidney Tissue Slide Segmentation',
#   'url': 'https://www.kaggle.com/competitions/hubmap-hacking-the-human-vasculature?ref=mlcontests',
#   'type': '📷 Computer Vision',
#   'tags': ['measurable', 'medical', 'supervised', 'vision', 'segmentation'],
#   'launched': '22 May 2023',
#   'registration-deadline': '24 Jul 2023',
#   'deadline': '31 Jul 2023',
#   'prize': '$50,000',
#   'platform': 'Kaggle',
#   'sponsor': 'HuBMAP',
#   'additional_urls': [],
#   'conference': None,
#   'conference-year': None,
# ...

# %%
df = pd.DataFrame(t['data'])

# %%
icra = df[(df.conference == 'ICRA') & (df['conference-year'] == 2023)]

# %%
icra
# Out:
#                                            name  \
# 35     ADAPT Human-Robot Collaborative Assembly
# 36  Robotic Bin Picking, Assembly, and Stacking
# 37                     Humanoid Robot Wrestling
# 38              Virtual Autonomous Drone Racing
# 39                       Build Assistive Robots
# 40                F1Tenth Autonomous Grand Prix
# 41     Robomaster University Sim2Real Challenge
# 42     Prepare an English Breakfast with Robots
# 43                   Quadruped Robot Challenges
# 44        Benchmark Autonomous Robot Navigation
#
#                                                   url        type  \
# 35  https://metricsproject.eu/agile-production/ada...  🤖 Robotics
# 36  https://www.sim4dexterity.de/en/icra-2023-comp...  🤖 Robotics
# 37  https://webots.cloud/run?version=R2023a&url=ht...  🤖 Robotics
# 38  https://uzh-rpg.github.io/drone-racing-competi...  🤖 Robotics
# 39  https://metricsproject.eu/healthcare/assistive...  🤖 Robotics
# ...

# %%
icra.to_csv('icra_competitions.csv')
